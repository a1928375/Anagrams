# %%
# Write a function, readwordlist, that takes a filename as input and returns a set of all the words and a set of all the 
# prefixes in that file, in uppercase. For testing, you can assume that you have access to a file called 'words4k.txt'

def prefixes(word):
    "A list of the initial sequences of a word, not including the complete word."
    
    return [word[:i] for i in range(len(word))]

def readwordlist(filename):
    """Read the words from a file and return a set of the words and a set of the prefixes."""
    
    file = open(filename) # opens file
    
    text = file.read().upper().split()    # gets file into string
    
    wordset   = set(text)
    
    prefixset = set(p for word in wordset for p in prefixes(word))
    
    return wordset, prefixset

WORDS, PREFIXES = readwordlist('words4k.txt')

#print (WORDS)
#print (PREFIXES)

a = list(PREFIXES)
a.sort()
print(a)

print (len(WORDS)    == 3892)
print (len(PREFIXES) == 6475)
print ('UMIAQS' in WORDS)
print ('MOVING' in WORDS)
print ('UNDERSTANDIN' in PREFIXES)
print ('ZOMB' in PREFIXES)
# Out:
# ['', 'A', 'AA', 'AB', 'ABI', 'ABIL', 'ABILI', 'ABILIT', 'ABL', 'ABO', 'ABOU', 'ABOV', 'ABS', 'ABSE', 'ABSEN', 'ABSENC', 'AC', 'ACC', 'ACCE', 'ACCEP', 'ACCO', 'ACCOR', 'ACCORD', 'ACCORDI', 'ACCORDIN', 'ACCOU', 'ACCOUN', 'ACCU', 'ACCUS', 'ACH', 'ACHI', 'ACHIE', 'ACHIEV', 'ACHIEVE', 'ACHIEVEM', 'ACHIEVEME', 'ACHIEVEMEN', 'ACR', 'ACRO', 'ACROS', 'ACT', 'ACTI', 'ACTIO', 'ACTION', 'ACTIV', 'ACTIVI', 'ACTIVIT', 'ACTU', 'ACTUA', 'ACTUAL', 'ACTUALL', 'AD', 'ADD', 'ADDI', 'ADDIT', 'ADDITI', 'ADDITIO', 'ADDITION', 'ADDITIONA', 'ADDR', 'ADDRE', 'ADDRES', 'ADE', 'ADEN', 'ADENI', 'ADENIN', 'ADENINE', 'ADENIT', 'ADENITI', 'ADEQ', 'ADEQU', 'ADEQUA', 'ADEQUAT', 'ADM', 'ADMI', 'ADMIN', 'ADMINI', 'ADMINIS', 'ADMINIST', 'ADMINISTR', 'ADMINISTRA', 'ADMINISTRAT', 'ADMINISTRATI', 'ADMINISTRATIO', 'ADMIR', 'ADO', 'ADOP', 'ADV', 'ADVA', 'ADVAN', 'ADVANC', 'ADVANT', 'ADVANTA', 'ADVANTAG', 'ADVE', 'ADVEN', 'ADVENT', 'ADVENTU', 'ADVENTUR', 'ADVER', 'ADVERT', 'ADVERTI', 'ADVERTIS', 'ADVI', 'ADVIS', 'AF', 'AFF', 
# ...
